# %%
#Importar libreria pandas
import pandas as pd

# %%
#Cargar Datos
df = pd.read_csv('/content/train.csv')

# %% [markdown]
# EXPLORACION DE LOS DATOS

# %%
#Tamaño conjunto de datos
df.shape
# Out:
# (101037, 21)

# %%
#Inspeccion inicial y estructura de los datos
df.head()
# Out:
#        ID  PERIODO_ACADEMICO            E_PRGM_ACADEMICO E_PRGM_DEPARTAMENTO  \
# 0  904256            20212.0                  ENFERMERIA              BOGOTÁ
# 1  645256            20212.0                     DERECHO           ATLANTICO
# 2  308367            20203.0       MERCADEO Y PUBLICIDAD              BOGOTÁ
# 3  470353            20195.0  ADMINISTRACION DE EMPRESAS           SANTANDER
# 4  989032            20212.0                  PSICOLOGIA           ANTIOQUIA
#
#                 E_VALORMATRICULAUNIVERSIDAD E_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones    Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                    0
# 2  Entre 2.5 millones y menos de 4 millones      Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                    0
# 4  Entre 2.5 millones y menos de 4 millones  Entre 21 y 30 horas
#
#   F_ESTRATOVIVIENDA F_TIENEINTERNET                    F_EDUCACIONPADRE  \
# ...

# %%
#Informacion General de los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101037 entries, 0 to 101036
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ID                           101037 non-null  int64
#  1   PERIODO_ACADEMICO            101036 non-null  float64
#  2   E_PRGM_ACADEMICO             101036 non-null  object
#  3   E_PRGM_DEPARTAMENTO          101036 non-null  object
#  4   E_VALORMATRICULAUNIVERSIDAD  100130 non-null  object
#  5   E_HORASSEMANATRABAJA         96509 non-null   object
#  6   F_ESTRATOVIVIENDA            96332 non-null   object
#  7   F_TIENEINTERNET              97150 non-null   object
#  8   F_EDUCACIONPADRE             97649 non-null   object
#  9   F_TIENELAVADORA              95296 non-null   object
#  10  F_TIENEAUTOMOVIL             94731 non-null   object
#  11  E_PRIVADO_LIBERTAD           101036 non-null  object
# ...

# %%
#Estadistica descriptiva de los datos
df.describe()
# Out:
#                   ID  PERIODO_ACADEMICO    INDICADOR_1    INDICADOR_2  \
# count  101037.000000      101036.000000  101036.000000  101036.000000
# mean   493630.214882       20198.362742       0.268979       0.259493
# std    285328.012211          10.519397       0.122101       0.093140
# min        11.000000       20183.000000       0.000000       0.000000
# 25%    247189.000000       20195.000000       0.204000       0.212000
# 50%    492239.000000       20195.000000       0.240000       0.271000
# 75%    740183.000000       20203.000000       0.314000       0.308000
# max    989276.000000       20213.000000       0.657000       0.487000
#
#          INDICADOR_3    INDICADOR_4
# count  101036.000000  101036.000000
# mean        0.262207       0.262777
# std         0.058925       0.068052
# min         0.000000       0.000000
# 25%         0.255000       0.255000
# 50%         0.277000       0.285000
# 75%         0.294000       0.302000
# max         0.320000       0.332000

# %%
#Nombre de las columnas del dataset
df.columns
# Out:
# Index(['ID', 'PERIODO_ACADEMICO', 'E_PRGM_ACADEMICO', 'E_PRGM_DEPARTAMENTO',
#        'E_VALORMATRICULAUNIVERSIDAD', 'E_HORASSEMANATRABAJA',
#        'F_ESTRATOVIVIENDA', 'F_TIENEINTERNET', 'F_EDUCACIONPADRE',
#        'F_TIENELAVADORA', 'F_TIENEAUTOMOVIL', 'E_PRIVADO_LIBERTAD',
#        'E_PAGOMATRICULAPROPIO', 'F_TIENECOMPUTADOR', 'F_TIENEINTERNET.1',
#        'F_EDUCACIONMADRE', 'RENDIMIENTO_GLOBAL', 'INDICADOR_1', 'INDICADOR_2',
#        'INDICADOR_3', 'INDICADOR_4'],
#       dtype='object')

# %%
#Veamos los elementos de la columna RENDIMIENTO GLOBAL
df['RENDIMIENTO_GLOBAL'].unique()
# Out:
# array(['medio-alto', 'bajo', 'alto', 'medio-bajo', nan], dtype=object)

# %%
#Veamos como esta distribuidas las clases en la columna RENDIMIENTO GLOBAL
df['RENDIMIENTO_GLOBAL'].value_counts()
# Out:
# RENDIMIENTO_GLOBAL
# alto          25435
# bajo          25318
# medio-alto    25250
# medio-bajo    25033
# Name: count, dtype: int64

# %%
#Veamos cuantos valores faltantes hay por columna
df.isnull().sum()
# Out:
# ID                                0
# PERIODO_ACADEMICO                 1
# E_PRGM_ACADEMICO                  1
# E_PRGM_DEPARTAMENTO               1
# E_VALORMATRICULAUNIVERSIDAD     907
# E_HORASSEMANATRABAJA           4528
# F_ESTRATOVIVIENDA              4705
# F_TIENEINTERNET                3887
# F_EDUCACIONPADRE               3388
# F_TIENELAVADORA                5741
# F_TIENEAUTOMOVIL               6306
# E_PRIVADO_LIBERTAD                1
# E_PAGOMATRICULAPROPIO           933
# F_TIENECOMPUTADOR              5540
# F_TIENEINTERNET.1              3887
# F_EDUCACIONMADRE               3463
# RENDIMIENTO_GLOBAL                1
# INDICADOR_1                       1
# INDICADOR_2                       1
# INDICADOR_3                       1
# INDICADOR_4                       1
# dtype: int64

# %%
#Ahora veamos la misma informacion en termino de porcentaje redondeado a 2
(df.isnull().sum() * 100 / len(df)).round(2)
# Out:
# ID                             0.00
# PERIODO_ACADEMICO              0.00
# E_PRGM_ACADEMICO               0.00
# E_PRGM_DEPARTAMENTO            0.00
# E_VALORMATRICULAUNIVERSIDAD    0.90
# E_HORASSEMANATRABAJA           4.48
# F_ESTRATOVIVIENDA              4.66
# F_TIENEINTERNET                3.85
# F_EDUCACIONPADRE               3.35
# F_TIENELAVADORA                5.68
# F_TIENEAUTOMOVIL               6.24
# E_PRIVADO_LIBERTAD             0.00
# E_PAGOMATRICULAPROPIO          0.92
# F_TIENECOMPUTADOR              5.48
# F_TIENEINTERNET.1              3.85
# F_EDUCACIONMADRE               3.43
# RENDIMIENTO_GLOBAL             0.00
# INDICADOR_1                    0.00
# INDICADOR_2                    0.00
# INDICADOR_3                    0.00
# INDICADOR_4                    0.00
# dtype: float64

# %%
#Evaluemo graficamente la distribucion entre las horas semana que trabaja el estudiantes
# y el redimiento global

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='E_HORASSEMANATRABAJA', hue='RENDIMIENTO_GLOBAL', data=df)
plt.xticks(rotation = 90);

# %% [markdown]
# La clase de los estudiantes que trabajan mas de 30 horas a la semana es la unica en la cual el rendimiento medio-bajo es mayor. Tambien podemos decir que la mayoria de estudiantes trabajan mas de 30 horas a la semana
